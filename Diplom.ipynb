# %% [markdown]
# <a href="https://colab.research.google.com/github/APrigarina/face_aging_scripts/blob/master/Diplom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# There are several branches on [git repository](https://github.com/APrigarina/Face-Aging-with-Identity-Preserved-Conditional-Generative-Adversarial-Networks.git):
#
#
# *   **Master** that contains main code to run and test GAN
# *   **mobilenet_face_aging** to take aging results with Mobilenet-v1 model
# *   **alexnet_face_aging** to take aging results with Alexnet Model
#
# ---

# %%
# !git clone https://github.com/APrigarina/Face-Aging-with-Identity-Preserved-Conditional-Generative-Adversarial-Networks.git
# Out:
# Cloning into 'Face-Aging-with-Identity-Preserved-Conditional-Generative-Adversarial-Networks'...
# remote: Enumerating objects: 206, done.
# remote: Counting objects: 100% (206/206), done.
# remote: Compressing objects: 100% (140/140), done.
# remote: Total 504 (delta 138), reused 132 (delta 66), pack-reused 298
# Receiving objects: 100% (504/504), 30.93 MiB | 32.92 MiB/s, done.
# Resolving deltas: 100% (269/269), done.

# %%
cd Face-Aging-with-Identity-Preserved-Conditional-Generative-Adversarial-Networks
# Out:
# /content/Face-Aging-with-Identity-Preserved-Conditional-Generative-Adversarial-Networks

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
# !cp "/content/drive/My Drive/Diploma/dataset/new_CACD.zip" ./

# %%
# !unzip -q new_CACD.zip

# %% [markdown]
# This Python skript used for start training process of GAN with specified parameters:

# %%
# !python age_lsgan_transfer.py \
  --gan_loss_weight=75 #@param {type:"number"} \
  --fea_loss_weight=0.5 #@param {type:"number"} \
  --age_loss_weight=35 #@param {type:"number"} \
  --fea_layer_name=conv_ds_14 #@param {type:"string"} \
  --checkpoint_dir="/content/drive/My Drive/Diploma/gan_with_pretrained" #@param {type:"string"} \
  --sample_dir="/content/drive/My Drive/Diploma/gan_with_pretrained" #@param {type:"string"}
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From age_lsgan_transfer.py:75: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From age_lsgan_transfer.py:199: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From age_lsgan_transfer.py:83: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0519 20:57:36.611281 140664156051328 module_wrapper.py:139] From age_lsgan_transfer.py:83: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %% [markdown]
# Run this script to start test:

# %%
# !python test.py
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From test.py:49: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From test.py:168: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From test.py:63: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# W0528 22:57:58.165080 139699790559104 module_wrapper.py:139] From test.py:63: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...

# %% [markdown]
# Get pretrained model:

# %%
# !python mobilenet_train.py \
  --checkpoint_dir="/content/drive/My Drive/Diploma/mobilenet_face_train_checkpoints" #@param {type:"string"}

# %%
# !python tools/generate_train_file.py
# Out:
# 11-20 3097 309 2788
# 21-30 12896 1289 11607
# 31-40 13672 1367 12305
# 41-50 12763 1276 11487
# 50+ 9999 999 9000

# %%
!(cd "/content/drive/My Drive/Diploma/dataset/" && zip -r -q new_CACD.zip new_CACD)

# %%
# !cp "/content/drive/My Drive/Diploma/dataset/new_CACD.zip" ./

# %%
# !unzip -q new_CACD.zip

# %%
# !python tools/generate_train_file.py
# Out:
# 2000

# %%
import os
import subprocess
for image_name in os.listdir('new_CACD/'):
  if image_name.startswith("\""):
    new_image_name = image_name.replace("\"", "")
    comand = "!(mv '" + image_name + "' " + new_image_name + ")"
    print(comand)
    os.system(comand)
    # print(new_image_name)
